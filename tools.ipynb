# %%
import os
import time
import logging
import googlemaps
from typing import List, Dict, Optional, Union, Set
from dotenv import load_dotenv

logger = logging.getLogger(__name__)

load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. Google API Nearby Search (Old) - Single Keyword

# %%
def search_places(location, radius=20000, keyword=None, language='en', max_pages=3, min_rating=0.0):
    """
    Search Google Places nearby with pagination support using the old/legacy API.
    Returns RAW API data without formatting.
    
    Args:
        location: (lat, lng) tuple or dict with 'lat'/'lng' keys  
        radius: search radius in meters (default 20km)
        keyword: optional search keyword
        language: language code (default 'en') 
        max_pages: maximum pages to fetch (1-3, each page = ~20 results)
        min_rating: minimum rating filter (0.0-5.0)
    
    Returns:
        List of raw place dictionaries from Google Places API
    """
    api_key = os.getenv('GOOGLE_MAPS_API_KEY')
    if not api_key:
        raise ValueError("GOOGLE_MAPS_API_KEY not set in environment")
    
    gmaps = googlemaps.Client(key=api_key)
    
    # Handle both tuple and dict location formats
    if isinstance(location, dict):
        # Handle both 'lng' and 'lon' keys
        lat = location['lat']
        lng = location.get('lng') or location.get('lon')
        location_tuple = (lat, lng)
    elif isinstance(location, (tuple, list)) and len(location) >= 2:
        location_tuple = (location[0], location[1])
    else:
        raise ValueError("location must be (lat, lng) tuple or dict with 'lat'/'lng' keys")
    
    # Validate parameters
    if not (1 <= max_pages <= 3):
        raise ValueError("max_pages must be between 1 and 3")
    if radius <= 0 or radius > 50000:
        raise ValueError("radius must be between 1 and 50000 meters")
    
    raw_results = []
    page_token = None
    pages_fetched = 0
    
    # Fetch pages with pagination
    while pages_fetched < max_pages:
        try:
            if page_token:
                print(f"Fetching page {pages_fetched + 1}...")
                time.sleep(2)  # Required delay for next_page_token
                response = gmaps.places_nearby(page_token=page_token, language=language)
            else:
                print("Fetching page 1...")
                response = gmaps.places_nearby(
                    location=location_tuple,
                    radius=radius,
                    keyword=keyword,
                    language=language
                )
        except googlemaps.exceptions.ApiError as e:
            logger.exception("Places API error: %s", e)
            break
        except Exception as e:
            logger.exception("Unexpected error in nearby search: %s", e)
            break
        
        # Collect raw results
        page_results = response.get('results', [])
        raw_results.extend(page_results)
        
        # Check for next page
        page_token = response.get('next_page_token')
        pages_fetched += 1
        
        if not page_token:
            print("No more pages available")
            break
    
    # Filter by rating - return raw data
    filtered_results = []
    for place in raw_results:
        # Check rating filter
        rating = place.get('rating', 0)
        if rating < min_rating:
            continue
        
        # Return the raw place data from Google API
        filtered_results.append(place)
    
    return filtered_results

# %%
## Testing single keyword
keyword="culture food"
results = search_places(
    location={"lat": 1.3521, "lng": 103.8198},
    radius=5000,
    keyword=keyword,
    min_rating=4.0
)

print(f"Found {len(results)} places:")
print(f"{results}")
# Out:
# Fetching page 1...
# No more pages available
# Found 13 places:
# [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.304977, 'lng': 103.8548091}, 'viewport': {'northeast': {'lat': 1.306270329892722, 'lng': 103.8562413798927}, 'southwest': {'lat': 1.303570670107278, 'lng': 103.8535417201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': 'Thien Long Vietnamese Food', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2160, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/
, 'photos': [{'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111700338186585466521">Soo Chung</a>'], 'photo_reference': 'AciIO2ex3k2LjAUgVz9DkAnzY9U7x3xyqn9PoyZrLvYabBq1d5vFd1G6IFC0o3NJJZB5Zg6IlCY2yBctz2l7iq7VREogBDaUsCtG6qdAvSnrrsm1rTEPQJ2H9AH1UtFX-csjTKbzKzGne6srzLwWCezcdPqDC5kisjwTrzkLqkPvf1FtdCPCQCYfNWzMbi5jjK65Gf5Ob1y84MvWNtfBhwuvLc3Lge1GtPu-YqQ_Kw2pIqjGonL4d2_5G_iwcNZY2fynLyqHAqenOMztoIbMV9ppHd ...

# %% [markdown]
# ## 2. Google API Nearby Search (Old) - Multiple Keywords

# %%
def search_multiple_keywords(location, keywords, radius=20000, max_pages=2, min_rating=4.0):
    """
    Search for multiple keywords and return raw results with deduplication.
    Returns RAW API data without formatting.
    
    Args:
        location: (lat, lng) tuple or dict with 'lat'/'lng' keys
        keywords: list of keywords to search for
        radius: search radius in meters
        max_pages: max pages per keyword (to avoid too many API calls)
        min_rating: minimum rating filter
    
    Returns:
        List of unique raw places from Google API
    """
    all_results = []
    seen_place_ids: Set[str] = set()
    
    for keyword in keywords:
        print(f"\n=== Searching for: '{keyword}' ===")
        
        try:
            # Use search_places instead of search_nearby (which doesn't exist)
            results = search_places(
                location=location,
                radius=radius,
                keyword=keyword,
                max_pages=max_pages,
                min_rating=min_rating
            )
            
            # Deduplicate by place_id
            new_results = []
            for place in results:
                place_id = place.get('place_id')
                if place_id and place_id not in seen_place_ids:
                    seen_place_ids.add(place_id)
                    new_results.append(place)
            
            all_results.extend(new_results)
            print(f"Added {len(new_results)} new unique places for '{keyword}' (total: {len(all_results)})")
            
        except Exception as e:
            print(f"Error searching for '{keyword}': {e}")
            continue
    
    return all_results

# %%
## Testing multiple keywords
keywords = ["culture food", "art museum", "local cuisine"]
results = search_multiple_keywords(
    location={"lat": 1.3521, "lng": 103.8198},
    radius=5000,
    keywords=keywords,
    min_rating=4.2
)

print(f"Found {len(results)} places:")
print(f"{results}")
# Out:
# === Searching for: 'culture food' ===
# Fetching page 1...
# Fetching page 2...
# No more pages available
# Added 21 new unique places for 'culture food' (total: 21)
#
# === Searching for: 'art museum' ===
# Fetching page 1...
# No more pages available
# Added 2 new unique places for 'art museum' (total: 23)
#
# === Searching for: 'local cuisine' ===
# Fetching page 1...
# No more pages available
# Added 12 new unique places for 'local cuisine' (total: 35)
# Found 35 places:
# [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.3088323, 'lng': 103.8546119}, 'viewport': {'northeast': {'lat': 1.310160329892722, 'lng': 103.8559478798927}, 'southwest': {'lat': 1.307460670107278, 'lng': 103.8532482201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#13B5C7', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Baroque House', 'opening_hours': {'open_now': True}, 'photos': [{'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111700338186585466521">Soo Chung</a>'], 'photo_reference': 'AciIO2dCEc08d_NFag9NeVLhvKTyd12PzQAY1kR23Z5cDDjlirWSPkFS2jmAgofZSTwntNohvW3aqtxlbSlsiCHZDrUf8Ch8B59hdXHQSx7BZoEjjTZYhwXBMWGWTKcxCC1EQt2sSrdU85Ayb_P9ksdd_0-_9U6f3-rE-iCHV61Cj42kcGZeGVZ_6Pv9JxQp2xsJuOPXGs1QzBzXV6jtwIt1QFUnJK4ecUmcONBpTgnCN3Ii1tXSr8Rz7DcCz10AqZ8qTQ5mO1VLqdysBxY6I8gdri4cKxq8vC7MKl6wpkXbFyls3D2eocwpaauqfxM5E1OQOKZN5QLTiw2ZEP
 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/10 ...

# %% [markdown]
# ## 3. Google API Place Details (Old)

# %%
def get_place_details(place_ids, fields=None, details_per_second=5.0, max_retries=3, language='en'):
    """
    Fetch detailed information for places using the old Places API.
    Returns RAW API data without formatting.
    
    Args:
        place_ids: List of place IDs to get details for
        fields: List of fields to retrieve (None for all basic fields)
        details_per_second: Rate limit for API calls
        max_retries: Number of retries for failed requests
        language: Language for results
    
    Returns:
        Dict mapping {place_id: raw_details_dict}
    """
    api_key = os.getenv('GOOGLE_MAPS_API_KEY')
    if not api_key:
        raise ValueError("GOOGLE_MAPS_API_KEY not set in environment")
    
    gmaps = googlemaps.Client(key=api_key)
    
    # Common fields for place details
    if fields is None:
        fields = [
            'name', 'formatted_address', 'geometry', 'opening_hours',
            'rating', 'website', 'price_level', 'type'
        ]
    
    details_by_id = {}
    sleep_between = 1.0 / details_per_second
    
    print(f"Getting details for {len(place_ids)} places...")
    
    for i, place_id in enumerate(place_ids, 1):
        print(f"Fetching details {i}/{len(place_ids)}: {place_id}")
        
        attempts = 0
        while attempts <= max_retries:
            try:
                response = gmaps.place(
                    place_id=place_id,
                    fields=fields,
                    language=language
                )
                # Return raw response from API
                details_by_id[place_id] = response.get('result', {})
                break  # Success
                
            except googlemaps.exceptions.ApiError as e:
                attempts += 1
                if attempts > max_retries:
                    logger.error("Details failed for %s after %d attempts: %s", place_id, attempts, e)
                    details_by_id[place_id] = {}
                    break
                
                backoff = 0.5 * (2 ** (attempts - 1))
                logger.warning("API error for %s, backing off %.2fs (attempt %d): %s", place_id, backoff, attempts, e)
                time.sleep(backoff)
                
            except Exception as e:
                logger.exception("Unexpected error for %s: %s", place_id, e)
                details_by_id[place_id] = {}
                break
        
        # Rate limiting
        time.sleep(sleep_between)
    
    return details_by_id

# %%
## Testing place details fetching
# keywords = ["tourist_attraction", "park"]
keywords = ["vegetarian", "cafe"]

# Get up to 40 results per keyword (2 pages × 20)
results = search_multiple_keywords(
    location={"lat": 1.3521, "lng": 103.8198},
    keywords=keywords,
    radius=25000,
    max_pages=1,  # page(s) per keyword
    min_rating=4.0
)

print(f"Found {len(results)} places:")
print(f"{results}")

# Extract place IDs for details fetching
top_place_ids = [place['place_id'] for place in results[:3]]  # Limit to top 3 for testing
print(f"{top_place_ids}")
detailed_info = get_place_details(
    place_ids=top_place_ids,
    details_per_second=2.0  # Be gentle on API
)

print(f"{detailed_info}")
# Out:
# === Searching for: 'vegetarian' ===
# Fetching page 1...
# Added 18 new unique places for 'vegetarian' (total: 18)
#
# === Searching for: 'cafe' ===
# Fetching page 1...
# Added 19 new unique places for 'cafe' (total: 37)
# Found 37 places:
# [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 1.3692862, 'lng': 103.9573534}, 'viewport': {'northeast': {'lat': 1.370646429892722, 'lng': 103.9588297298927}, 'southwest': {'lat': 1.367946770107278, 'lng': 103.9561300701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': 'Fu Kang Ting Vegetarian Food 24 hours 富康庭素食軒 @ East Singapore (Pasir Ris)', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106984500801046219400">24 hours Vegetarian Food @ East Singapore (Pasir Ris)</a>'], 'photo_reference': 'AciIO2e2yrvGTtnoALRr3BDWl5NfM-aCYXRdlaRyZ06ySVKRWwU63Fn2CnzVrVY0kYhDLyorUJztzCHAkX7bAQua2Sc1JAV_1kqowFz__trATfi43U9H9Bpe4OjlE9HqhJuTEA0eoZoHSvWkexWBzTI9OSCypF0os
, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111262543742034247920">Stefan</a>'], 'photo_reference': 'AciIO2dzz1bsn2Y_Cr_WoX3Y5bvIF5NNgoIM529AOZYLP9wT7rYxkXMAEjtHqFTlkFExibhXJ8FbkBoYhR55tPEefhK4SSUYzRoIYGb8Zbr18PtY5oH1pqVQtpVzF50Ua3fd ...
# ['ChIJLzral5M92jERglrAxDjQDXU', 'ChIJsWkrBM8P2jER241ct6s5TbA', 'ChIJNd6qDbsZ2jERXzGkcSP3wvI']
# Getting details for 3 places...
# Fetching details 1/3: ChIJLzral5M92jERglrAxDjQDXU
# Fetching details 2/3: ChIJsWkrBM8P2jER241ct6s5TbA
# Fetching details 3/3: ChIJNd6qDbsZ2jERXzGkcSP3wvI
# {'ChIJLzral5M92jERglrAxDjQDXU': {'formatted_address': 'Blk 443 Paris ris Drive 6, Coffee Express 2000 food court Stall 3 (Just opposite the, drink stall, Singapore 510443', 'geometry': {'location': {'lat': 1.3692862, 'lng': 103.9573534}, 'viewport': {'northeast': {'lat': 1.370645580291502, 'lng': 103.9588288802915}, 'southwest': {'lat': 1.367947619708498, 'lng': 103.9561309197085}}}, 'name': 'Fu Kang Ting Vegetarian Food 24 hours 富康庭素食軒 @ East Singapore (Pasir Ris)', 'opening_hours': {'open_now': True, 'periods': [{'open': {'day': 0, 'time': '0000'}}], 'weekday_text': ['Monday: Open 24 hours', 'Tuesday: Open 24 hours', 'Wednesday: Open 24 hours', 'Thursday: Open 24 hours', 'Friday: Open 24 hours', 'Saturday: Open 24 hours', 'Sunday: Open 24 hours']}, 'rating': 4.1, 'types': ['establishment', 'food', 'point_of_interest', 'restaurant']}, 'ChIJsWkrBM8P2jER241ct6s5TbA': {'formatted_address': '959 Jurong West Street 92, Singapore 640959', 'geometry': {'location': {'lat': 1.3415846, 'lng': 103.690471}, 'viewport': {'northeast': {'lat': 1.342948430291502, 'lng': 103.6917062302915}, 'southwest': {'lat': 1.340250469708498, 'lng': 103.6890082697085}}}, 'name': 'Jia Jia Vegetarian', 'rating': 4.4, 'types': ['establishment', 'food', 'point_of_interest', 'restaurant']}, 'ChIJNd6qDbsZ2jERXzGkcSP3wvI': {'formatted_address': '#01-16, 190 Middle Rd, Fortune Centre, Singapore 188979', 'geometry': {'location': {'lat': 1.3005706, 'lng': 103.8520847}, 'viewport': {'northeast': {'lat': 1.301819880291502, 'lng': 103.8533396302915}, 'southwest': {'lat': 1.299121919708498, 'lng': 103.8506416697085}}}, 'name': 'Tian Yuan Healthy Vegetarian Food Paradise', 'opening_hours': {'open_now': False, 'periods': [{'close': {'day': 1, 'time': '1930'}, 'open': {'day': 1, 'time': '1030'}}, {'close': {'day': 2, 'time': '1930'}, 'open': {'day': 2, 'time': '1030'}}, {'close': {'day': 3, 'time': '1930'}, 'open': {'day': 3, 'time': '1030'}}, {'close': {'day': 4, 'time': '1930'}, 'open': {'day': 4, 'time': '1030'}}, {'close': {'day': 5, 'time': '1930'}, 'open': {'day': 5, 'time': '1030'}}, {'close': {'day': 6, 'time': '1930'}, 'open': {'day': 6, 'time': '1030'}}], 'weekday_text': ['Monday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Tuesday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Wednesday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Thursday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Friday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Saturday: 10:30\u202fAM\u2009–\u20097:30\u202fPM', 'Sunday: Closed']}, 'rating': 4.8, 'types': ['establishment', 'food', 'point_of_interest', 'restaurant']}}
